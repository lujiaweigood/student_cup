# %% [markdown]
# 手順：以下のファイルを読み込み順次に実行する

# %% [markdown]
# ###  １、前処理部分

# %%
# データセット表示用コード
# %matplotlib inline
# Cleaning
#df = df.dropna()
import pandas as pd
from pivottablejs import pivot_ui
import pandas_profiling

import datetime
import jpholiday

import matplotlib.pyplot as plt
import seaborn as sns
from pandas_highcharts.display import display_charts
import pandas as pd
import numpy as np
pd.options.display.precision = 20
dataframe2 = pd.read_csv('/users/lujiawei/student/stadium_capacity_mapping.csv', engine='python')
dataframe = pd.read_csv('/users/lujiawei/student/train.csv', engine='python')

dataframe3 = pd.read_csv('/users/lujiawei/student/match_reports.csv', engine='python')
# データセット表示用コード


import pandas as pd
import numpy as np

test_old = pd.read_csv('/users/lujiawei/student/test.csv', engine='python')


people = pd.read_csv('/users/lujiawei/people3.csv', engine='python')




P2006 = pd.read_csv('/users/lujiawei/2006P.csv', engine='python')
P2007 = pd.read_csv('/users/lujiawei/2007P.csv', engine='python')
P2008 = pd.read_csv('/users/lujiawei/2008P.csv', engine='python')
P2009 = pd.read_csv('/users/lujiawei/2009P.csv', engine='python')
P2010 = pd.read_csv('/users/lujiawei/2010P.csv', engine='python')
P2011 = pd.read_csv('/users/lujiawei/2011P.csv', engine='python')
P2012 = pd.read_csv('/users/lujiawei/2012P.csv', engine='python')
P2013 = pd.read_csv('/users/lujiawei/2013P.csv', engine='python')
P2014 = pd.read_csv('/users/lujiawei/2014P.csv', engine='python')
P2015 = pd.read_csv('/users/lujiawei/2015P.csv', engine='python')
P2016 = pd.read_csv('/users/lujiawei/2016P.csv', engine='python')
P2017 = pd.read_csv('/users/lujiawei/2017P.csv', engine='python')
P2018 = pd.read_csv('/users/lujiawei/2018P.csv', engine='python')


a2005 = pd.read_csv('/users/lujiawei/2005.csv', engine='python')
a2006 = pd.read_csv('/users/lujiawei/2006.csv', engine='python')
a2007 = pd.read_csv('/users/lujiawei/2007.csv', engine='python')
a2008 = pd.read_csv('/users/lujiawei/2008.csv', engine='python')
a2009 = pd.read_csv('/users/lujiawei/2009.csv', engine='python')
a2010 = pd.read_csv('/users/lujiawei/2010.csv', engine='python')
a2011 = pd.read_csv('/users/lujiawei/2011.csv', engine='python')
a2012 = pd.read_csv('/users/lujiawei/2012.csv', engine='python')
a2013 = pd.read_csv('/users/lujiawei/2013.csv', engine='python')
a2014 = pd.read_csv('/users/lujiawei/2014.csv', engine='python')
a2015 = pd.read_csv('/users/lujiawei/2015.csv', engine='python')
a2016 = pd.read_csv('/users/lujiawei/2016.csv', engine='python')
a2017 = pd.read_csv('/users/lujiawei/2017.csv', engine='python')
a2018 = pd.read_csv('/users/lujiawei/2018.csv', engine='python')
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas_profiling/base.py:20: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/Users/lujiawei/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/lujiawei/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/lujiawei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/lujiawei/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
# ...

# %%
#値を入れた後のtest_oldをプロット

# %%
test_old
# Out:
#         id  match_date kick_off_time section round home_team away_team  \
# 0    19075  2017-02-25         12:35     第1節   第1日      横浜FM        浦和
# 1    19076  2017-02-25         14:04     第1節   第1日        仙台        札幌
# 2    19077  2017-02-25         14:04     第1節   第1日        鹿島      FC東京
# 3    19078  2017-02-25         14:04     第1節   第1日        清水        神戸
# 4    19079  2017-02-25         14:04     第1節   第1日        広島        新潟
# 5    19080  2017-02-25         14:05     第1節   第1日        鳥栖         柏
# 6    19081  2017-02-25         15:03     第1節   第1日       C大阪        磐田
# 7    19082  2017-02-25         16:03     第1節   第1日        大宮       川崎F
# 8    19083  2017-02-26         17:03     第1節   第2日       G大阪        甲府
# 9    19084  2017-03-04         14:01     第2節   第1日        浦和       C大阪
# 10   19085  2017-03-04         14:04     第2節   第1日        甲府        鹿島
# 11   19086  2017-03-04         14:04     第2節   第1日        広島        清水
# ...

# %%
set(test_old['venue']) - set(dataframe['venue'])
# Out:
# {'トランスコスモススタジアム長崎', 'パナソニックスタジアム吹田', '三協フロンテア柏スタジアム'}

# %%
#二つの場所は建て替えられていてるだけで、人数が同じで置き換えました。
test_old["venue"].replace(['パナソニックスタジアム吹田'], ['市立吹田サッカースタジアム'],inplace=True)
test_old["venue"].replace(['三協フロンテア柏スタジアム'], ['日立柏サッカー場'],inplace=True)

# %%
#字体を揃える

# %%
test_old["home_team"].replace(['Ｃ大阪'], ['C大阪'],inplace=True)
test_old["away_team"].replace(['Ｃ大阪'], ['C大阪'],inplace=True)
test_old["home_team"].replace(['川崎Ｆ'], ['川崎F'],inplace=True)
test_old["away_team"].replace(['川崎Ｆ'], ['川崎F'],inplace=True)
test_old["home_team"].replace(['Ｇ大阪'], ['G大阪'],inplace=True)
test_old["away_team"].replace(['Ｇ大阪'], ['G大阪'],inplace=True)

# %%
#入場人数を収容者数で割って収容率を求める。

# %%
for i in dataframe2['stadium']:
    for k in dataframe['venue']:
        if i == k:
            m  =(dataframe[(dataframe[u'venue']==k)]['attendance'].values.astype('float64'))/int(dataframe2[(dataframe2[u'stadium']==i)]['capacity'].values)
            mask = (dataframe['venue']==k)
            dataframe.loc[mask, 'attendance'] = m
            break

# %%
#1を超える収容率は１に直す

# %%
dataframe.loc[dataframe['attendance']>1,'attendance' ] =1.0

# %%
dataframe.loc[dataframe['attendance']==0,'attendance' ]
# Out:
# 2479    0.0
# Name: attendance, dtype: float64

# %%
#収容率＝０の異常値は捨てる

# %%
l = dataframe.drop(2479, axis=0,inplace = True)

# %%
y = dataframe['attendance'].astype(np.float64)

# %%
k= dataframe.drop(['attendance'],axis=1,inplace=True)

# %%
dataframe  =  pd.concat([dataframe,test_old])
df = dataframe

# %%
#kick_off_timeの時間を分解しました、match_dateの時間を、年、月、日に分解しました。

# %%
pp = df["kick_off_time"]
tmp = []

for i in pp:
    d = datetime.datetime.strptime(i, "%H:%M")
    tmp.append(d.hour)
df["time"] = tmp

# %%
df['time'] = df['time'].astype('str')

# %%
pp = df["match_date"]
tmp = []

for i in pp:
    d = datetime.datetime.strptime(i, "%Y-%m-%d")
    tmp.append(d.year)

df["year"] = tmp
df['year'] = df['year'].astype('str')

# %%
pp = df["match_date"]
tmp = []

for i in pp:
    d = datetime.datetime.strptime(i, "%Y-%m-%d")
    tmp.append(d.weekday())

df["weekday"] = tmp
df['weekday'] = df['weekday'].astype('str')

# %%
pp = df["match_date"]
tmp = []

for i in pp:
    d = datetime.datetime.strptime(i, "%Y-%m-%d")
    tmp.append(d.month)

df["month"] = tmp
df["month"] = df["month"].astype('str')

# %%
pp = df["match_date"]
tmp = []

for i in pp:
    d = datetime.datetime.strptime(i, "%Y-%m-%d")
    tmp.append(d.day)

df["day"] = tmp
df["day"] = df["day"].astype('str')

# %%
#broadcastersの値を/で分割して、カテゴリー変数を利用するため NaN 値をパディングして、文字列に変換する。

# %%
broadcast = []
for i in df['broadcasters'].str.split('/').values:
    for k in i:
        broadcast.append(k)

# %%
broadcast = set(broadcast)

# %%
broadcast =list(broadcast)

# %%
df['broadcasters'] = df['broadcasters'].fillna('')

# %%
for broad in broadcast:
    df[broad] = df['broadcasters'].str.contains(broad)
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
df[broadcast] = df[broadcast].values.astype('str')

# %%
import pandas_datareader.data as pdr

# %%
#チーム別の試合がこの年度の平均入場者数をダウンロードして利用しました。

# %%
df2006 = df[df['match_date'].str.contains('2006')]
df2007 = df[df['match_date'].str.contains('2007')]
df2008 = df[df['match_date'].str.contains('2008')]
df2009 = df[df['match_date'].str.contains('2009')]
df2010 = df[df['match_date'].str.contains('2010')]
df2011 = df[df['match_date'].str.contains('2011')]
df2012 = df[df['match_date'].str.contains('2012')]
df2013 = df[df['match_date'].str.contains('2013')]
df2014 = df[df['match_date'].str.contains('2014')]
df2015 = df[df['match_date'].str.contains('2015')]
df2016 = df[df['match_date'].str.contains('2016')]
df2017 = df[df['match_date'].str.contains('2017')]
df2018 = df[df['match_date'].str.contains('2018')]

# %%
for h in P2006['Ｊ１']:
    for j1 in df2006['home_team']:
        if h==j1:
            m  =P2006[(P2006[u'Ｊ１']==h)]['Unnamed: 4'].values.astype('float64')
            mask = (df2006['home_team']==j1)
            df2006.loc[mask, 'home_team_average'] = m
            break
for h in P2006['Ｊ１']:
    for j1 in df2006['away_team']:
        if h==j1:
            m  =P2006[(P2006[u'Ｊ１']==h)]['Unnamed: 4'].values.astype('float64')
            mask = (df2006['away_team']==j1)
            df2006.loc[mask, 'away_team_average'] = m
            break
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for h in P2007['Ｊ１']:
    for j1 in df2007['home_team']:
        if h==j1:
            m  =P2007[(P2007[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2007['home_team']==j1)
            df2007.loc[mask, 'home_team_average'] = m
            break

for h in P2007['Ｊ１']:
    for j1 in df2007['away_team']:
        if h==j1:
            m  =P2007[(P2007[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2007['away_team']==j1)
            df2007.loc[mask, 'away_team_average'] = m
            break
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for h in P2008['Ｊ１']:
    for j1 in df2008['home_team']:
        if h==j1:
            m  =P2008[(P2008[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2008['home_team']==j1)
            df2008.loc[mask, 'home_team_average'] = m
            break
            
for h in P2008['Ｊ１']:
    for j1 in df2008['away_team']:
        if h==j1:
            m  =P2008[(P2008[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2008['away_team']==j1)
            df2008.loc[mask, 'away_team_average'] = m
            break
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for h in P2009['Ｊ１']:
    for j1 in df2009['home_team']:
        if h==j1:
            m  =P2009[(P2009[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2009['home_team']==j1)
            df2009.loc[mask, 'home_team_average'] = m
            break
            
            
for h in P2009['Ｊ１']:
    for j1 in df2009['away_team']:
        if h==j1:
            m  =P2009[(P2009[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2009['away_team']==j1)
            df2009.loc[mask, 'away_team_average'] = m
            break
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for h in P2010['Ｊ１']:
    for j1 in df2010['home_team']:
        if h==j1:
            m  =P2010[(P2010[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2010['home_team']==j1)
            df2010.loc[mask, 'home_team_average'] = m
            break
            
            
for h in P2010['Ｊ１']:
    for j1 in df2010['away_team']:
        if h==j1:
            m  =P2010[(P2010[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2010['away_team']==j1)
            df2010.loc[mask, 'away_team_average'] = m
            break
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for h in P2011['Ｊ１']:
    for j1 in df2011['home_team']:
        if h==j1:
            m  =P2011[(P2011[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2011['home_team']==j1)
            df2011.loc[mask, 'home_team_average'] = m
            break
            
            
for h in P2011['Ｊ１']:
    for j1 in df2011['away_team']:
        if h==j1:
            m  =P2011[(P2011[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2011['away_team']==j1)
            df2011.loc[mask, 'away_team_average'] = m
            break
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for h in P2012['Ｊ１']:
    for j1 in df2012['home_team']:
        if h==j1:
            m  =P2012[(P2012[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2012['home_team']==j1)
            df2012.loc[mask, 'home_team_average'] = m
            break
            
for h in P2012['Ｊ１']:
    for j1 in df2012['away_team']:
        if h==j1:
            m  =P2012[(P2012[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2012['away_team']==j1)
            df2012.loc[mask, 'away_team_average'] = m
            break
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for h in P2013['Ｊ１']:
    for j1 in df2013['home_team']:
        if h==j1:
            m  =P2013[(P2013[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2013['home_team']==j1)
            df2013.loc[mask, 'home_team_average'] = m
            break
            
            
for h in P2013['Ｊ１']:
    for j1 in df2013['away_team']:
        if h==j1:
            m  =P2013[(P2013[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2013['away_team']==j1)
            df2013.loc[mask, 'away_team_average'] = m
            break
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for h in P2014['Ｊ１']:
    for j1 in df2014['home_team']:
        if h==j1:
            m  =P2014[(P2014[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2014['home_team']==j1)
            df2014.loc[mask, 'home_team_average'] = m
            break
            
for h in P2014['Ｊ１']:
    for j1 in df2014['away_team']:
        if h==j1:
            m  =P2014[(P2014[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2014['away_team']==j1)
            df2014.loc[mask, 'away_team_average'] = m
            break
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for h in P2015['Ｊ１']:
    for j1 in df2015['home_team']:
        if h==j1:
            m  =P2015[(P2015[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2015['home_team']==j1)
            df2015.loc[mask, 'home_team_average'] = m
            break
            
            
for h in P2015['Ｊ１']:
    for j1 in df2015['away_team']:
        if h==j1:
            m  =P2015[(P2015[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2015['away_team']==j1)
            df2015.loc[mask, 'away_team_average'] = m
            break
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for h in P2016['Ｊ１']:
    for j1 in df2016['home_team']:
        if h==j1:
            m  =P2016[(P2016[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2016['home_team']==j1)
            df2016.loc[mask, 'home_team_average'] = m
            break
            
            
for h in P2016['Ｊ１']:
    for j1 in df2016['away_team']:
        if h==j1:
            m  =P2016[(P2016[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2016['away_team']==j1)
            df2016.loc[mask, 'away_team_average'] = m
            break
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for h in P2017['Ｊ１']:
    for j1 in df2017['home_team']:
        if h==j1:
            m  =P2017[(P2017[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2017['home_team']==j1)
            df2017.loc[mask, 'home_team_average'] = m
            break
            
            
for h in P2017['Ｊ１']:
    for j1 in df2017['away_team']:
        if h==j1:
            m  =P2017[(P2017[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2017['away_team']==j1)
            df2017.loc[mask, 'away_team_average'] = m
            break
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
for h in P2018['Ｊ１']:
    for j1 in df2018['home_team']:
        if h==j1:
            m  =P2018[(P2018[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2018['home_team']==j1)
            df2018.loc[mask, 'home_team_average'] = m
            break
            
            
for h in P2018['Ｊ１']:
    for j1 in df2018['away_team']:
        if h==j1:
            m  =P2018[(P2018[u'Ｊ１']==j1)]['Unnamed: 4'].values.astype('float64')
            mask = (df2018['away_team']==j1)
            df2018.loc[mask, 'away_team_average'] = m
            break
# Out:
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/lujiawei/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df_test = pd.concat([df2017,df2018])
df = pd.concat([df2006,df2007,df2008,df2009,df2010,df2011,df2012,df2013,df2014,df2015,df2016,df_test])

# %%
#年別の通算勝敗表をダウンロード、をランク付けで、チーム別の勝利する回数高いほど、低い数字にして、処理する。一番勝利回数は多いチームは１にします。重複値の場合は、平均値を取る。

# %%
a2005['総勝'] = a2005['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')
a2006['総勝'] = a2006['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')
a2007['総勝'] = a2007['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')
a2008['総勝'] = a2008['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')
a2009['総勝'] = a2009['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')
a2010['総勝'] = a2010['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')
a2011['総勝'] = a2011['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')
a2012['総勝'] = a2012['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')
a2013['総勝'] = a2013['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')
a2014['総勝'] = a2014['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')
a2015['総勝'] = a2015['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')
a2016['総勝'] = a2016['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')
a2017['総勝'] = a2017['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')
a2018['総勝'] = a2018['総勝'].rank(method="average",numeric_only=True,ascending=False).astype('float64')

# %%
#チーム別の勝利する回数をそれぞれのチームに入れる

# %%
for h in a2006['チーム']:
    for j1 in df2006['home_team']:
        if h==j1:
            m  =a2006[(a2006[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2006['home_team']==j1)
            df2006.loc[mask, 'home_team_win'] = m
            break
for h in a2006['チーム']:
    for j1 in df2006['away_team']:
        if h==j1:
            m  =a2006[(a2006[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2006['away_team']==j1)
            df2006.loc[mask, 'away_team_win'] = m
            break

# %%
for h in a2007['チーム']:
    for j1 in df2007['home_team']:
        if h==j1:
            m  =a2007[(a2007[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2007['home_team']==j1)
            df2007.loc[mask, 'home_team_win'] = m
            break
for h in a2007['チーム']:
    for j1 in df2007['away_team']:
        if h==j1:
            m  =a2007[(a2007[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2007['away_team']==j1)
            df2007.loc[mask, 'away_team_win'] = m
            break

# %%
for h in a2008['チーム']:
    for j1 in df2008['home_team']:
        if h==j1:
            m  =a2008[(a2008[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2008['home_team']==j1)
            df2008.loc[mask, 'home_team_win'] = m
            break
for h in a2008['チーム']:
    for j1 in df2008['away_team']:
        if h==j1:
            m  =a2008[(a2008[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2008['away_team']==j1)
            df2008.loc[mask, 'away_team_win'] = m
            break

# %%
for h in a2009['チーム']:
    for j1 in df2009['home_team']:
        if h==j1:
            m  =a2009[(a2009[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2009['home_team']==j1)
            df2009.loc[mask, 'home_team_win'] = m
            break
for h in a2009['チーム']:
    for j1 in df2009['away_team']:
        if h==j1:
            m  =a2009[(a2009[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2009['away_team']==j1)
            df2009.loc[mask, 'away_team_win'] = m
            break

# %%
for h in a2010['チーム']:
    for j1 in df2010['home_team']:
        if h==j1:
            m  =a2010[(a2010[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2010['home_team']==j1)
            df2010.loc[mask, 'home_team_win'] = m
            break
for h in a2010['チーム']:
    for j1 in df2010['away_team']:
        if h==j1:
            m  =a2010[(a2010[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2010['away_team']==j1)
            df2010.loc[mask, 'away_team_win'] = m
            break

# %%
for h in a2011['チーム']:
    for j1 in df2011['home_team']:
        if h==j1:
            m  =a2011[(a2011[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2011['home_team']==j1)
            df2011.loc[mask, 'home_team_win'] = m
            break
for h in a2011['チーム']:
    for j1 in df2011['away_team']:
        if h==j1:
            m  =a2011[(a2011[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2011['away_team']==j1)
            df2011.loc[mask, 'away_team_win'] = m
            break

# %%
for h in a2012['チーム']:
    for j1 in df2012['home_team']:
        if h==j1:
            m  =a2012[(a2012[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2012['home_team']==j1)
            df2012.loc[mask, 'home_team_win'] = m
            break
for h in a2012['チーム']:
    for j1 in df2012['away_team']:
        if h==j1:
            m  =a2012[(a2012[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2012['away_team']==j1)
            df2012.loc[mask, 'away_team_win'] = m
            break

# %%
for h in a2013['チーム']:
    for j1 in df2013['home_team']:
        if h==j1:
            m  =a2013[(a2013[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2013['home_team']==j1)
            df2013.loc[mask, 'home_team_win'] = m
            break
for h in a2013['チーム']:
    for j1 in df2013['away_team']:
        if h==j1:
            m  =a2013[(a2013[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2013['away_team']==j1)
            df2013.loc[mask, 'away_team_win'] = m
            break

# %%
for h in a2014['チーム']:
    for j1 in df2014['home_team']:
        if h==j1:
            m  =a2014[(a2014[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2014['home_team']==j1)
            df2014.loc[mask, 'home_team_win'] = m
            break
            
for h in a2014['チーム']:
    for j1 in df2014['away_team']:
        if h==j1:
            m  =a2014[(a2014[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2014['away_team']==j1)
            df2014.loc[mask, 'away_team_win'] = m
            break

# %%
for h in a2015['チーム']:
    for j1 in df2015['home_team']:
        if h==j1:
            m  =a2015[(a2015[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2015['home_team']==j1)
            df2015.loc[mask, 'home_team_win'] = m
            break
            
for h in a2015['チーム']:
    for j1 in df2015['away_team']:
        if h==j1:
            m  =a2015[(a2015[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2015['away_team']==j1)
            df2015.loc[mask, 'away_team_win'] = m
            break

# %%
for h in  a2016['チーム']:
    for j1 in df2016['home_team']:
        if h==j1:
            m  =a2016[(a2016[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2016['home_team']==j1)
            df2016.loc[mask, 'home_team_win'] = m
            break
            
for h in  a2016['チーム']:
    for j1 in df2016['away_team']:
        if h==j1:
            m  =a2016[(a2016[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2016['away_team']==j1)
            df2016.loc[mask, 'away_team_win'] = m
            break

# %%
for h in a2017['チーム']:
    for j1 in df2017['home_team']:
        if h==j1:
            m  =a2017[(a2017[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2017['home_team']==j1)
            df2017.loc[mask, 'home_team_win'] = m
            break
            
for h in a2017['チーム']:
    for j1 in df2017['away_team']:
        if h==j1:
            m  =a2017[(a2017[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2017['away_team']==j1)
            df2017.loc[mask, 'away_team_win'] = m
            break

# %%
for h in a2018['チーム']:
    for j1 in df2018['home_team']:
        if h==j1:
            m  =a2018[(a2018[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2018['home_team']==j1)
            df2018.loc[mask, 'home_team_win'] = m
            break
            
for h in a2018['チーム']:
    for j1 in df2018['away_team']:
        if h==j1:
            m  =a2018[(a2018[u'チーム']==j1)]['総勝'].values.astype('float64')
            mask = (df2018['away_team']==j1)
            df2018.loc[mask, 'away_team_win'] = m
            break

# %%
df_test = pd.concat([df2017,df2018])

# %%
df = pd.concat([df2006,df2007,df2008,df2009,df2010,df2011,df2012,df2013,df2014,df2015,df2016,df_test])

# %%
df['home_team_win'] = df['home_team_win'].astype('float64')

# %%
df['away_team_win'] = df['away_team_win'].astype('float64')

# %%
#スタジアムの収容人数データを入れる

# %%
for i in dataframe2['stadium']:
    for k in df['venue']:
        if i == k:
            mask = (df['venue']==k)
            m  =dataframe2[(dataframe2[u'stadium']==i)]['capacity'].values
            df.loc[mask, 'capacity'] = m
            break

# %%
#暑すぎあるいは寒すぎるのデータをカテゴリ変数に直す

# %%
df['暑すぎあるいは寒すぎる'] = None

# %%
for i, k in enumerate(df['temperature']):
    if k>=28 or k<= 11 :
        df['暑すぎあるいは寒すぎる'].values[i] =str(0)
    else:
        df['暑すぎあるいは寒すぎる'].values[i] =str(1)

# %%
#不快指数を作る、0.81×温度＋0.01×湿度×（0.99×温度-14.3）＋46.3>77を不快とする、温度と湿度を、カテゴリ変数に直す

# %%
df['不快指数'] = None

# %%
#0.81×温度＋0.01×湿度×（0.99×温度-14.3）＋46.3
for i, k in enumerate(df['temperature']):
    for  h in df['humidity']:
        if 0.81*k + 0.01* h*(0.99*k-14.3)+ 46.3>77 :
            df['不快指数'].values[i] =str(1)
        else:
            df['不快指数'].values[i] =str(0)
        break

# %%
#休日と祝日のデータを入れる

# %%
df["date"] = df["match_date"].apply(lambda x: datetime.datetime.strptime(x.split(" ")[0],'%Y-%m-%d'))

df["date"] = df["date"].apply(lambda x: datetime.date(x.year, x.month, x.day))

national_holiday = list(dict(jpholiday.holidays(df["date"].min(), df["date"].max())).keys())#祝日APIで期間内の祝日を取得

df["day"] = df["date"].apply(lambda x:x.isoweekday())#曜日を付与
df["holiday"] = df["date"].apply(lambda x:[1 if (x.isoweekday()>5)|(x in national_holiday) else 0][0])#土日祝を休日とする
all_holiday = list(set(df[df["holiday"]==1]["date"]))#全休日のリストを生成

dataframe = df
dataframe['holiday'] =dataframe['holiday'].astype('str')
dataframe['day'] =dataframe['day'].astype('str')

# %%
#sectionデータをカテゴリ変数に直す

# %%
import itertools
m = []
for i in dataframe['section']:
    k = float([''.join(it) for _, it in itertools.groupby(i, str.isdigit)][1])
    m.append(k)
dataframe['section'] = m

# %%
dataframe['section'] = dataframe['section'].astype('float')

# %%
#'date','id','match_date','kick_off_time','humidity','temperature','round'を削除する
k= dataframe.drop(['date','id','match_date','kick_off_time','humidity','temperature'],axis=1,inplace=True)

# %%
dataframe.columns
# Out:
# Index(['section', 'round', 'home_team', 'away_team', 'venue', 'weather',
#        'broadcasters', 'home_team_superstar', 'away_team_superstar', 'time',
#        ...
#        'スカパー・e2(TBSチャンネル)', 'テレビ山梨', 'home_team_average', 'away_team_average',
#        'home_team_win', 'away_team_win', 'capacity', '暑すぎあるいは寒すぎる', '不快指数',
#        'holiday'],
#       dtype='object', length=201)

# %%
#weatherを雨降るか降らないかというカテゴリー変数に直す

# %%
dataframe["weather"].replace(['曇'], ['晴'],inplace=True)
dataframe["weather"].replace(['晴のち曇'], ['晴'],inplace=True)
dataframe["weather"].replace(['屋内'], ['晴'],inplace=True)
dataframe["weather"].replace(['晴のち曇一時雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['晴のち雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['晴のち雪'], ['雨'],inplace=True)
dataframe["weather"].replace(['晴一時曇'], ['晴'],inplace=True)
dataframe["weather"].replace(['晴一時雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['晴一時雨のち曇'], ['雨'],inplace=True)
dataframe["weather"].replace(['晴時々曇'], ['晴'],inplace=True)
dataframe["weather"].replace(['晴時々曇一時雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['晴時々雪'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇のち晴'], ['晴'],inplace=True)
dataframe["weather"].replace(['曇のち雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇のち雨のち屋内'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇のち雨のち晴'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇のち雨のち曇'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇のち雨一時雷'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇のち雷雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇一時晴'], ['晴'],inplace=True)
dataframe["weather"].replace(['曇時々晴のち屋内'], ['晴'],inplace=True)
dataframe["weather"].replace(['曇時々晴一時雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇時々雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇時々雨のち晴'], ['雨'],inplace=True)
dataframe["weather"].replace(['雨のち曇一時雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇時々雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['雨一時雷雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇時々雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['雨時々晴'], ['雨'],inplace=True)
dataframe["weather"].replace(['雨時々曇'], ['雨'],inplace=True)
dataframe["weather"].replace(['雷雨のち曇'], ['雨'],inplace=True)
dataframe["weather"].replace(['霧'], ['晴'],inplace=True)
dataframe["weather"].replace(['曇一時雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇一時雨のち晴'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇一時雨のち曇'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇一時雷雨のち雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇時々晴'], ['晴'],inplace=True)
dataframe["weather"].replace(['曇時々雪'], ['雨'],inplace=True)
dataframe["weather"].replace(['雨のち晴'], ['雨'],inplace=True)
dataframe["weather"].replace(['雨のち曇'], ['雨'],inplace=True)
dataframe["weather"].replace(['雨のち曇のち晴'], ['雨'],inplace=True)
dataframe["weather"].replace(['雨のち曇時々雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['雨一時曇'], ['雨'],inplace=True)
dataframe["weather"].replace(['雨一時曇のち雨'], ['雨'],inplace=True)
dataframe["weather"].replace(['雪'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇一時雷雨のち曇'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇のち霧'], ['晴'],inplace=True)
dataframe["weather"].replace(['曇時々雨のち曇'], ['雨'],inplace=True)
dataframe["weather"].replace(['曇晴'], ['晴'],inplace=True)
dataframe["weather"].replace(['雨のち曇のち雨'], ['雨'],inplace=True)

# %%
set(dataframe["weather"])
# Out:
# {nan, '晴', '雨'}

# %%
dataframe = pd.get_dummies(dataframe)

# %%
train_x =dataframe

# %%
#連続変数全てをfloatに揃える

train_x['capacity'] = train_x['capacity'].astype('float64')
train_x['section'] = train_x['section'].astype('float64')

# %%
train_x['home_team_average'] = train_x['home_team_average'].astype('float64')
train_x['away_team_average'] = train_x['away_team_average'].astype('float64')

# %%
test = train_x[3365:]
train_x =  train_x[:3365]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train,y_test = train_test_split(train_x, y ,test_size=0.2,shuffle= True)

# %%
import xgboost as xgb
xgdmat=xgb.DMatrix(X_train,y_train)
deval = xgb.DMatrix(X_test, y_test)

# %% [markdown]
# ###   2、学習部分

# %%
watchlist = [(deval, 'eval')]

our_params={'booster': 'gbtree','eta':0.001,'seed':0,'subsample':0.5,'colsample_bytree':0.8,'objective':'reg:logistic','max_depth':1000,'min_child_weight':1,'eval_metric': 'rmse'}
final_gb=xgb.train(our_params,xgdmat,13000,watchlist,obj=None,feval=None,maximize=False,early_stopping_rounds=None,
evals_result=None,verbose_eval=True,xgb_model=None)
tesdmat=xgb.DMatrix(X_test)
y_pred=final_gb.predict(tesdmat)
print(y_pred)
# Out:
# [16:01:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 0 pruned nodes, max_depth=22
# [0]	eval-rmse:0.221863
# [16:01:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 0 pruned nodes, max_depth=16
# [1]	eval-rmse:0.221726
# [16:01:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 198 extra nodes, 0 pruned nodes, max_depth=13
# [2]	eval-rmse:0.221594
# [16:01:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 0 pruned nodes, max_depth=14
# [3]	eval-rmse:0.221466
# [16:01:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 0 pruned nodes, max_depth=15
# [4]	eval-rmse:0.221337
# [16:01:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 0 pruned nodes, max_depth=16
# [5]	eval-rmse:0.221208
# [16:01:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 0 pruned nodes, max_depth=18
# [6]	eval-rmse:0.221083
# ...

# %%
#収容率のテストデータの精度をプロットする
import matplotlib.pyplot as plt
plt.plot(y_test.values, label='rent')
plt.plot(y_pred, label='predict')
plt.legend()
plt.show()

# %%
import math

#A function to calculate Root Mean Squared Logarithmic Error (RMSLE)
def rmsle(y, y_pred):
	assert len(y) == len(y_pred)
	terms_to_sum = [(math.log(y_pred[i] + 1) - math.log(y[i] + 1)) ** 2.0 for i,pred in enumerate(y_pred)]
	return (sum(terms_to_sum) * (1.0/len(y))) ** 0.5

# %%
#収容率のテストデータの精度をプロットする

# %%
rmsle(y_test.values,y_pred)
# Out:
# 0.06655115627825918

# %% [markdown]
# ###   ３、予測部分

# %%
tesdmat=xgb.DMatrix(test)
y_pred2=final_gb.predict(tesdmat)
pd.options.display.precision = 20

# %%
y_pred3  =pd.DataFrame(y_pred2, dtype='float64')

# %%
y_pred3.columns = ['attendance']

# %%
test3 = pd.concat([test_old,y_pred3] ,axis = 1)

# %%
for i in dataframe2['stadium']:
    for k in test3['venue']:
        if i == k:
            m  =(test3[(test3[u'venue']==k)]['attendance'].values.astype('float64'))*int(dataframe2[(dataframe2[u'stadium']==i)]['capacity'].values)
            mask = (test3['venue']==k)
            test3.loc[mask, 'attendance'] = m
            break

# %%
len(test3['attendance'].values)
# Out:
# 477

# %%
#予測結果

# %%
test3
# Out:
#         id  match_date kick_off_time section round home_team away_team  \
# 0    19075  2017-02-25         12:35     第1節   第1日      横浜FM        浦和
# 1    19076  2017-02-25         14:04     第1節   第1日        仙台        札幌
# 2    19077  2017-02-25         14:04     第1節   第1日        鹿島      FC東京
# 3    19078  2017-02-25         14:04     第1節   第1日        清水        神戸
# 4    19079  2017-02-25         14:04     第1節   第1日        広島        新潟
# 5    19080  2017-02-25         14:05     第1節   第1日        鳥栖         柏
# 6    19081  2017-02-25         15:03     第1節   第1日       C大阪        磐田
# 7    19082  2017-02-25         16:03     第1節   第1日        大宮       川崎F
# 8    19083  2017-02-26         17:03     第1節   第2日       G大阪        甲府
# 9    19084  2017-03-04         14:01     第2節   第1日        浦和       C大阪
# 10   19085  2017-03-04         14:04     第2節   第1日        甲府        鹿島
# 11   19086  2017-03-04         14:04     第2節   第1日        広島        清水
# ...

# %%
submission = pd.Series(test3['attendance'].values)
submission.index =test_old.id
submission.to_csv('/Users/lujiawei/submissions_studnts.csv',index_label='id')

# %%
#モデルを保存

# %%
final_gb.save_model('/Users/lujiawei/submissions_studnts.model')

# %%
#変数重要度プロット

# %%
xgb.plot_importance(final_gb, importance_type='weight',
      max_num_features=7)

# %%
for i in dataframe.columns:
    print(i)
# Out:
# section
# home_team_average
# away_team_average
# home_team_win
# away_team_win
# capacity
# round_第1日
# round_第2日
# round_第3日
# round_第4日
# home_team_C大阪
# home_team_FC東京
# home_team_G大阪
# home_team_京都
# home_team_仙台
# home_team_千葉
# home_team_名古屋
# home_team_大分
# home_team_大宮
# home_team_山形
# home_team_川崎F
# home_team_広島
# home_team_徳島
# home_team_新潟
# home_team_札幌
# home_team_東京V
# home_team_松本
# home_team_柏
# home_team_横浜FC
# home_team_横浜FM
# home_team_浦和
# home_team_清水
# home_team_湘南
# home_team_甲府
# home_team_磐田
# home_team_神戸
# home_team_福岡
# home_team_長崎
# home_team_鳥栖
# home_team_鹿島
# away_team_C大阪
# away_team_FC東京
# away_team_G大阪
# away_team_京都
# away_team_仙台
# away_team_千葉
# away_team_名古屋
# away_team_大分
# away_team_大宮
# away_team_山形
# away_team_川崎F
# away_team_広島
# away_team_徳島
# away_team_新潟
# away_team_札幌
# away_team_東京V
# away_team_松本
# away_team_柏
# away_team_横浜FC
# away_team_横浜FM
# away_team_浦和
# away_team_清水
# away_team_湘南
# away_team_甲府
# away_team_磐田
# ...

# %%
df.columns
# Out:
# Index(['section', 'round', 'home_team', 'away_team', 'venue', 'weather',
#        'broadcasters', 'time', 'year', 'weekday',
#        ...
#        'スカパー・e2(TBSチャンネル)', 'テレビ山梨', 'home_team_average', 'away_team_average',
#        'home_team_win', 'away_team_win', 'capacity', '暑すぎあるいは寒すぎる', '不快指数',
#        'holiday'],
#       dtype='object', length=199)
